# %%
import pandas as pd

# %%
car_sales = pd.read_csv('https://raw.githubusercontent.com/ashutosh-kedar/data_analysis_ml/refs/heads/main/data/car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.iloc[7]
# Out:
# Make                 Honda
# Colour                Blue
# Odometer (KM)        54738
# Doors                    4
# Price            $7,000.00
# Name: 7, dtype: object

# %%
car_sales.loc[7]
# Out:
# Make                 Honda
# Colour                Blue
# Odometer (KM)        54738
# Doors                    4
# Price            $7,000.00
# Name: 7, dtype: object

# %%
car_sales_shuffled = car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 7   Honda   Blue          54738      4   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00
# 6   Honda   Blue          45698      4   $7,500.00
# 0  Toyota  White         150043      4   $4,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
car_sales_shuffled.loc[7] # .loc is based on the index
# Out:
# Make                 Honda
# Colour                Blue
# Odometer (KM)        54738
# Doors                    4
# Price            $7,000.00
# Name: 7, dtype: object

# %%
car_sales_shuffled.iloc[7] # .iloc is based on position index
# Out:
# Make                 Honda
# Colour                 Red
# Odometer (KM)        87899
# Doors                    4
# Price            $5,000.00
# Name: 1, dtype: object

# %% [markdown]
# ## Slicing using loc and iloc

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 7   Honda   Blue          54738      4   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00
# 6   Honda   Blue          45698      4   $7,500.00
# 0  Toyota  White         150043      4   $4,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
car_sales_shuffled.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 7   Honda   Blue          54738      4   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 8  Toyota  White          60000      4   $6,250.00

# %%
car_sales_shuffled.loc[:3]
# Out:
#     Make Colour  Odometer (KM)  Doors       Price
# 7  Honda   Blue          54738      4   $7,000.00
# 3    BMW  Black          11179      5  $22,000.00

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 7   Honda   Blue          54738      4   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00
# 6   Honda   Blue          45698      4   $7,500.00
# 0  Toyota  White         150043      4   $4,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
car_sales_shuffled.reset_index(drop=True) # drop true will drop the reshuffled index and only keep the resetted index
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0   Honda   Blue          54738      4   $7,000.00
# 1     BMW  Black          11179      5  $22,000.00
# 2  Toyota  White          60000      4   $6,250.00
# 3  Nissan  White          31600      4   $9,700.00
# 4   Honda   Blue          45698      4   $7,500.00
# 5  Toyota  White         150043      4   $4,000.00
# 6  Toyota   Blue          32549      3   $7,000.00
# 7   Honda    Red          87899      4   $5,000.00
# 8  Nissan  White         213095      4   $3,500.00
# 9  Toyota  Green          99213      4   $4,500.00

# %%
car_sales[car_sales['Odometer (KM)'] > 70000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00

# %%
# we will first group by using categorical field and then aggregate the numerical field

car_sales.groupby(car_sales['Make']).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %% [markdown]
# ## Ploting the graph

# %%
import matplotlib.pyplot as plt

# %%
car_sales['Odometer (KM)'].plot()
# Out:
# <Axes: >

# %%
car_sales['Odometer (KM)'].hist()
# Out:
# <Axes: >

# %%
car_sales['Price'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
car_sales['Price_Int'] = car_sales['Price'].str.split('.',regex=False).str[0]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Price_Int
# 0  Toyota  White         150043      4   $4,000.00    $4,000
# 1   Honda    Red          87899      4   $5,000.00    $5,000
# 2  Toyota   Blue          32549      3   $7,000.00    $7,000
# 3     BMW  Black          11179      5  $22,000.00   $22,000
# 4  Nissan  White         213095      4   $3,500.00    $3,500
# 5  Toyota  Green          99213      4   $4,500.00    $4,500
# 6   Honda   Blue          45698      4   $7,500.00    $7,500
# 7   Honda   Blue          54738      4   $7,000.00    $7,000
# 8  Toyota  White          60000      4   $6,250.00    $6,250
# 9  Nissan  White          31600      4   $9,700.00    $9,700

# %%
car_sales['Price_Int'] = car_sales['Price_Int'].str.replace('[$,.]', '',regex=True).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Price_Int
# 0  Toyota  White         150043      4   $4,000.00       4000
# 1   Honda    Red          87899      4   $5,000.00       5000
# 2  Toyota   Blue          32549      3   $7,000.00       7000
# 3     BMW  Black          11179      5  $22,000.00      22000
# 4  Nissan  White         213095      4   $3,500.00       3500
# 5  Toyota  Green          99213      4   $4,500.00       4500
# 6   Honda   Blue          45698      4   $7,500.00       7500
# 7   Honda   Blue          54738      4   $7,000.00       7000
# 8  Toyota  White          60000      4   $6,250.00       6250
# 9  Nissan  White          31600      4   $9,700.00       9700

# %%
car_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     str
#  1   Colour         10 non-null     str
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     str
#  5   Price_Int      10 non-null     int64
# dtypes: int64(3), str(3)
# memory usage: 612.0 bytes

# %%
car_sales['Price_Int'].plot()
# Out:
# <Axes: >
