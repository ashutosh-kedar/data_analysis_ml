# %%
import pandas as pd

# %%
fruits_series = pd.Series(['apple','mango','banana'])
fruits_series
# Out:
# 0     apple
# 1     mango
# 2    banana
# dtype: str

# %%
prices_series = pd.Series([12,43,78])
prices_series
# Out:
# 0    12
# 1    43
# 2    78
# dtype: int64

# %%
fruits_series.dtypes
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
fruits_prices_df = pd.DataFrame({'fruits':fruits_series,'prices':prices_series})
fruits_prices_df
# Out:
#    fruits  prices
# 0   apple      12
# 1   mango      43
# 2  banana      78
